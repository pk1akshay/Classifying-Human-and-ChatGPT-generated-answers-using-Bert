# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/final.csv')
df = df[['title','body', 'label']]
df.head()
# Out:
#                                                title  \
# 0  Any Advice On How to Not Be A Bitter PhD Student?
# 1     What is the true state of humanities academia?
# 2  A friend has offered to give me some Ostrich a...
# 3  When did humans begin using blankets/sheets an...
# 4          Anywhere to find reference for pig bones?
#
#                                                 body  label
# 0  I'm not a PhD student but I am on my way to ob...      0
# 1  Historian here. I know quite a few historians ...      0
# 2  Ostrich Eggs are awesome and easy. I make at l...      0
# 3  Humans have been using blankets and sleeping i...      1
# 4  It exists! This looks good: https://peterborou...      0

# %%
# Replace symbols in the 'body' column
df['body'] = df['body'].str.replace('â', "'")
df['title'] = df['title'].str.replace('â', "'")
# Display the first 20 rows
df.head(20)
# Out:
#                                                 title  \
# 0   Any Advice On How to Not Be A Bitter PhD Student?
# 1      What is the true state of humanities academia?
# 2   A friend has offered to give me some Ostrich a...
# 3   When did humans begin using blankets/sheets an...
# 4           Anywhere to find reference for pig bones?
# 5   Is Hierarchy and Power (in a social context) h...
# 6   I feel unloved constantly. Venus squares. What...
# 7   Despite breaking up and getting back together ...
# 8   What are some realistic career options in fiel...
# 9   Should I join my supervisor starting a new res...
# 10  My flat/uni mate is (pretty much) only passing...
# 11  Can pork loin a la porchetta be scaled down wi...
# 12  I'm just getting into this.. is there anything...
# 13  Does anyone have advice for or is willing to h...
# 14  Why did ancient peoples feel justified in ruin...
# 15  Do we know life (and the climate) was like in ...
# 16         Did I get the right size All Clad skillet?
# 17  Can you fine people please look at this sinast...
# 18  What's a good way to approach a former professor?
# 19  trying to get into fresh pasta, what shapes an...
#
#                                                  body  label
# 0   I'm not a PhD student but I am on my way to ob...      0
# 1   Historian here. I know quite a few historians ...      0
# 2   Ostrich Eggs are awesome and easy. I make at l...      0
# 3   Humans have been using blankets and sleeping i...      1
# 4   It exists! This looks good: https://peterborou...      0
# 5   In my opinion, the concept of hierarchy and po...      1
# 6   i'm not an expert, but my input:\n\nvenus in a...      0
# 7   You are in an on-again, off-again relationship...      0
# 8   There are several realistic career options in ...      1
# 9   Well, that's a tough decision to make! Joining...      1
# 10  It sounds like you're in a tough situation wit...      1
# 11  Hey! You can certainly do a smaller version of...      0
# 12  When I look at "life path" I like to look at t...      0
# 13  Absolutely! I'd be happy to help you with a re...      1
# 14  Well, ancient peoples had a different perspect...      1
# 15  I found a paper about climate and human evolut...      0
# 16  Well, it depends on what you're looking for! A...      1
# 17  Everyone has good and not so good aspects in s...      0
# 18  When approaching a former professor, it's impo...      1
# 19  Oh, I love fresh pasta! It's so much better th...      1

# %%
df['label'].value_counts()
# Out:
# 0    6948
# 1    6948
# Name: label, dtype: int64

# %%
# Create a new column 'input' by concatenating 'title' and 'body' with a colon separator
combined_text = df['title'] + ' ' + df['body']
labels = df['label']

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.35.0-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 38.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 32.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 80.5 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 44.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 28.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.35.0

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification
from torch.utils.data import DataLoader, TensorDataset

# %%
# Step 2: Split the Data
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(combined_text, labels, test_size=0.2, random_state=42)

# %%
# Step 3: Tokenization and Formatting
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
train_encodings = tokenizer(list(X_train), truncation=True, padding=True, return_tensors='pt', max_length=512)
val_encodings = tokenizer(list(X_val), truncation=True, padding=True, return_tensors='pt', max_length=512)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
train_dataset = TensorDataset(train_encodings.input_ids, train_encodings.attention_mask, torch.tensor(y_train.values))
val_dataset = TensorDataset(val_encodings.input_ids, val_encodings.attention_mask, torch.tensor(y_val.values))

# %%
# Step 4: Model Training
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)
# Out:
# Downloading model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

# %% [markdown]
# With Dropout 0.2

# %%
# Step 4: Model Training with dropout
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)
model.dropout.p = 0.2  # Set dropout to 0.2
model.to(device)
# Step 5: Define optimizer and loss function
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5)
loss_fn = torch.nn.CrossEntropyLoss()

# Step 6: Training loop
best_val_loss = float('inf')
num_epochs = 5  # Adjust this as needed

for epoch in range(num_epochs):
    model.train()
    total_train_loss = 0

    for batch in train_loader:
        input_ids, attention_mask, labels = batch
        input_ids, attention_mask, labels = input_ids.to(device), attention_mask.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        total_train_loss += loss.item()

        loss.backward()
        optimizer.step()

    avg_train_loss = total_train_loss / len(train_loader)

    # Step 7: Validation loop
    model.eval()
    total_val_loss = 0

    with torch.no_grad():  # Disable gradient computation
        for batch in test_loader:
            input_ids, attention_mask, labels = batch
            input_ids, attention_mask, labels = input_ids.to(device), attention_mask.to(device), labels.to(device)

            outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
            loss = outputs.loss
            total_val_loss += loss.item()

    avg_val_loss = total_val_loss / len(test_loader)

    print(f'Epoch {epoch + 1}:')
    print(f'Training Loss: {avg_train_loss:.4f}')
    print(f'Validation Loss: {avg_val_loss:.4f}')

    # Step 8: Save the best model
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model.state_dict(), 'best_model2.pth')

print('Training complete.')
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1:
# Training Loss: 0.0465
# Validation Loss: 0.0286
# Epoch 2:
# Training Loss: 0.0047
# Validation Loss: 0.0095
# Epoch 3:
# Training Loss: 0.0037
# Validation Loss: 0.0088
# Epoch 4:
# Training Loss: 0.0002
# Validation Loss: 0.0169
# Epoch 5:
# Training Loss: 0.0001
# Validation Loss: 0.0187
# Training complete.

# %%
import numpy as np
# Load the best model
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)
model.load_state_dict(torch.load('best_model2.pth'))
model.to(device)
model.eval()

# Define a DataLoader for your test data (similar to how you did for validation)
# test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# Initialize lists to store predictions and true labels
predictions = []
true_labels = []

with torch.no_grad():
    for batch in test_loader:
        input_ids, attention_mask, labels = batch
        input_ids, attention_mask, labels = input_ids.to(device), attention_mask.to(device), labels.to(device)

        outputs = model(input_ids, attention_mask=attention_mask)
        logits = outputs.logits

        predictions.extend(torch.argmax(logits, dim=1).tolist())
        true_labels.extend(labels.tolist())

# Convert the predictions and true labels to numpy arrays for further analysis
predictions = np.array(predictions)
true_labels = np.array(true_labels)

# Calculate accuracy
accuracy = np.mean(predictions == true_labels)
print(f'Accuracy: {accuracy * 100:.2f}%')

# You can also use classification metrics like precision, recall, F1-score, etc. depending on your specific use case.

# Optional: Print a classification report
from sklearn.metrics import classification_report
target_names = ['Class 0', 'Class 1']  # Replace with your actual class names
print(classification_report(true_labels, predictions, target_names=target_names))
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Accuracy: 99.78%
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00      1440
#      Class 1       1.00      1.00      1.00      1340
#
#     accuracy                           1.00      2780
#    macro avg       1.00      1.00      1.00      2780
# weighted avg       1.00      1.00      1.00      2780

# %%
predictions = []
true_labels = []

with torch.no_grad():
    for batch in test_loader:
        input_ids, attention_mask, labels = batch
        input_ids, attention_mask, labels = input_ids.to(device), attention_mask.to(device), labels.to(device)

        outputs = model(input_ids, attention_mask=attention_mask)
        logits = outputs.logits

        predictions.extend(torch.argmax(logits, dim=1).tolist())
        true_labels.extend(labels.tolist())

# Convert the predictions and true labels to numpy arrays for further analysis
predictions = np.array(predictions)
true_labels = np.array(true_labels)


# Display some test cases and their corresponding outputs
num_cases_to_display = 10
for i in range(num_cases_to_display):
    print(f'Test Case {i+1}:')
    print(f'Input Text: {X_val.iloc[i]}')  # Corrected access to input text
    print(f'Predicted Class: {predictions[i]}')
    print(f'True Class: {true_labels[i]}')
    print('\n')
# Out:
# Test Case 1:
# Input Text: How does scholarly consensus work in the humanities and social sciences? Scholarly consensus in the humanities and social sciences is a fascinating and complex process. Unlike in the natural sciences, where experiments and empirical evidence often lead to more definitive conclusions, consensus in these fields is often more nuanced and subject to ongoing debate.
#
# In the humanities, such as literature, philosophy, and history, consensus is typically reached through a combination of rigorous analysis, interpretation, and critical discourse. Scholars engage in extensive research, examining primary and secondary sources, and presenting their findings through publications and academic conferences. Through this process, they contribute to the existing body of knowledge and engage in dialogue with their peers.
#
# In the social sciences, which include disciplines like sociology, psychology, and anthropology, consensus is often built through empirical research, statistical analysis, and theoretical frameworks. Researchers conduct studies, collect data, and analyze it using various methodologies. They then publish their findings in academic journals, where they are subject to peer review and critique. Over time, as more studies are conducted and replicated, patterns and trends emerge, leading to the formation of consensus.
#
# However, it's important to note that consensus in the humanities and social sciences is not static. It is subject to revision and evolution as new evidence, perspectives, and theories emerge. Scholars engage in ongoing debates, challenging existing ideas and proposing alternative interpretations. This process of critical inquiry and intellectual exchange is what drives progress and ensures that knowledge in these fields remains dynamic and responsive to new insights.
#
# Ultimately, scholarly consensus in the humanities and social sciences is a collective endeavor, shaped by the contributions of numerous scholars over time. It is a reflection of the current state of knowledge, but it is always open to further exploration and refinement.
# Predicted Class: 1
# True Class: 1
#
#
# Test Case 2:
# Input Text: Did women in hunter gatherer societies ever do the hunting? Yes they do. Probably the most famous group of women to do so anthropologically are the Martu women of Western Australia. You can watch a video about them [here](http://fora.tv/2012/04/28/Beyond_Women_the_Gatherer_Womens_Cooperative_Hunting). These women hunt ~ 80% of the game meat acquired by the tribe. [This article](http://www.stanford.edu/~rbird/rbird/Publications_files/whywomenhunt.pdf) on them is available for free and gives a fascinating overview to them, and explains the differences between social strategies among women and men hunters in Martu society. Women seem inclined to hunt smaller game, for a lower risk but lower gain strategy; their focus is largely on feeding people in their support network, children, and same-sex kin. Men, meanwhile, tend to hunt larger game that has a much higher risk -- ie, the men's hunting habits may not feed people every day -- and use hunting as a political strategy to gain favour for their families rather than a subsistence strategy. [Scelza and Bird](http://link.springer.com/article/10.1007/s12110-008-9041-5) (2008) also show evidence that there are divisions of labour amongst women -- ie, that women do not pursue the same subsistence/hunting strategy over the course of their lives, but instead change it based on age/social standing (as in, married, not married, of childbearing years, etc.). If those two articles left you wanting more, you can also read [this one](http://www.sciencedirect.com/science/article/pii/S109051381100050X) which elaborates on cooperative hunting strategies amongst Martu women -- sorry, behind a paywall for most I think.
# Predicted Class: 0
# True Class: 0
#
#
# Test Case 3:
# Input Text: Can someone take a peak at my now completely anonymous CV? Sure, I'd be happy to take a look at your anonymous CV! Just send it over and I'll do my best to provide some feedback or suggestions.
# Predicted Class: 1
# True Class: 1
#
#
# Test Case 4:
# Input Text: I haven't been in a committed relationship in 7 years (I'm 29 years old). Is it my nature to be alone or will i ever find someone? You're destiny is not written in the stars but in how you navigate life's difficulties and circumstances. Astrology is just a road map to overcome past hurts and pains and become stronger.
#
# On that note, you desperately want a committed relationship because your Sun, Mercury, Mars and Pluto are all in Scorpio and Scorpio is the sign of sex, commitment and change. You define yourself literally by the kind of relationship you will share with your chosen loved one and you want this relationship to last a life time and to be almost magical and transformative. A hohum, boring, and steady relationship doesn't suit you. You want excitement, tension and a deepening bond that will make the two of you unbreakable. This high aim of your relationship makes it more difficult to find a partner but not impossible. You will definitely find this person in the work place where you share similar career goals and understanding of one another. Also North Node in Capricorn in the 8th house also indicates to me you will have difficulty with deep transformative experiences because you are used to stability and safety of the second house, the house of material goods and items. You have to create a structure around your marriage goals and dive deep into yourself to understand what you want, need and desperately enjoy in a relationship. You probably have been so used in your comfort zone and you put your family first that you undermine the vision you want for yourself. I say get out there, get hurt, heal and learn. You will find the love of your life if you allow yourself these things.
# Predicted Class: 0
# True Class: 0
#
#
# Test Case 5:
# Input Text: Plagiarism and exclusion from a master's program? &gt; I did not do it on purpose, and it was all an unintentional mistake because of my own lack of knowledge of academic writing and lack of guidance from my professors.
#
# You're doing a graduate degree. Which implies that you have an undergraduate degree. Plagiarism (and how not to do it) is something you should have learned about years ago. Don't try and blame your professors for this now.
#
# &gt; the writing and paraphrasing have not been efficient
#
# I'm always rather suspect when people talk about efficient/effective paraphrasing. Because it comes across as them trying to find the lowest effort route to rewording someone else's work, as opposed to trying to understand and convey the information themselves. The former can be done by an AI program, there is no academic merit there.
#
# &gt; not citing common knowledge while being identically used
#
# What does this even mean? Have you copied actual sentences without paraphrasing because you figured it was common knowledge? If it is common knowledge you shouldn't even need to paraphrase since you'd be writing from your own knowledge, so I don't see how it would then get flagged as being identically used.
#
# &gt; The permanent exclusion seems disproportionate punishment
#
# It isn't. Academic dishonesty is a serious matter. If you were in your first year of undergrad and this was a one time offence *then* it would be. But you have multiple instances of plagiarism *including in your thesis*, and quite frankly if you've "accidentally" plagiarised now, I wouldn't be surprised if you didn't "accidentally" plagiarise all through your undergraduate degree, and it just wasn't picked up.
#
# Now, you might read all of that and think that I sound rather harsh and judgemental. But firstly, my points are all valid. And secondly, the people on your committee will likely have some (if not all) of the same thoughts. Do not approach this like you're a victim. Don't act like you don't deserve consequences. And don't blame your professors for not teaching you something you should have figured out years ago. None of these things will inspire sympathy in the committee, they will likely find those arguments as ridiculous and aggravating as I do. And that will not help your outcome.
#
# You need to be honest about the fact that *you* screwed up, and make clear that you have learned from this experience and won't make the same mistakes again. Don't try and push for leniency (that would likely backfire), instead take responsibility.
# Predicted Class: 0
# True Class: 0
#
#
# Test Case 6:
# Input Text: My SO and I seem to have a lot of differing placements in our charts (I, Left, have many Aquarius placements, and heavy 7th and 8th house, he, Right, has a Scorpio Stellium in the 9th house)... What does this mean for our compatibility? Any insight is greatly appreciated!! Your SO's chart reminds me a looooot of mine! (I share many planets in Scorpio, moon in Aries and mars Aquarius, plus the degrees of the Scorpio planets are almost identical to mine). My first love was an Aquarius and to this day was the most respectful and respectable man I've met. His (your man) mars being in Aquarius and your Venus being in Aquarius has a lot to do with it. Typically if you see someone's mars sign in someone else Venus, there's a lot of attraction - mars is the planet of directed energy so his directed energy is going straight to your Venus (the planet of love). Makes perfect sense to me.
#
# I personally think that Scorpio and Aquarius combos are an underrated compatibility match. While it may sometimes me a be it boring for Scorpio (we want CONSTANT passion and intensity) and a bit over-stimulating for Aquarius (like to detach and be rational, rather than emotional), I find that with the right placements of the other planets in the respective charts it can balance out like a yin yang. You can both learn a lot from each other, Aquarius can help Scorpio come out of their shell a bit when it comes to being more âotherâ minded and Scorpio can help teach Aquarius to be a bit more bold and willing to enrich their own life experience.
#
# Your sun signs also speak to your obvious compatibility too - Pisces and Scorpios tend to be super hot for each other. These charts feel super compatible to me.
#
# I think it's a sexy combo, tbh ð
# Predicted Class: 0
# True Class: 0
#
#
# Test Case 7:
# Input Text: how would u describe someone with mars in pisces? mars in pisces operate on a spiritual level, think spirit realm. a lot of a mars in pisces energy is used unknowingly through dreams, fantasies, deep soul searching... a lot of people think lazy/passive/weak but its deeper than that. we revive ourselves through subconscious, the invisible realm, being alone. this person thrives on solitude. they need a lot of time to retreat, process and heal. this is a very powerful and spiritual placement. This is a person who prefers to stay behind the scenes and act in hidden ways not because they are sneaky, its just the way they approach things. they are extremely sensitive. These people get lost in other worlds, realms, fantasies. They literally slip in and out of reality. This is why these people are perceived as inactive and etc.. Mostly due to the idea that their energy is being used and pulled in so many different ways. Mars in Pisces person may not be aware or realize this until they explore themselves deeper. I would def check on OJC astrology channel on youtube her video on Mars in Pisces is the most in depth and accurate analysis I have ever come across. I am mars in pisces as well and never come across a more accurate reading of mars in pisces. It put a lot of things in perspective for me
# Predicted Class: 0
# True Class: 0
#
#
# Test Case 8:
# Input Text: I have what appear to be four placements in my twelfth house. Anyone have any insight about these particular placements and what they may mean? What is your understanding of the twelfth house? I'm a bit of a novice here and deeply curious. Gracias! Hey there! The twelfth house in astrology is often associated with hidden or subconscious aspects of our lives. It's a complex and mysterious house that can reveal a lot about our inner world. Having four placements in your twelfth house sounds quite significant!
#
# Now, without knowing the specific placements, it's a bit challenging to give you a detailed interpretation. However, I can give you a general idea of what these placements might mean. The twelfth house is often linked to spirituality, intuition, dreams, and the unconscious mind. It can also represent solitude, isolation, and even self-sabotage at times.
#
# Having multiple placements in this house could suggest that these themes play a prominent role in your life. It might indicate a strong connection to your intuition, a rich dream life, or a deep interest in exploring your subconscious. It's worth noting that the twelfth house can also be associated with healing and self-discovery, so these placements might indicate a potential for personal growth and transformation.
#
# Remember, though, that astrology is highly individual, and the interpretation of these placements can vary depending on the specific planets, signs, and aspects involved. It's always a good idea to consult with a professional astrologer who can provide you with a more personalized analysis based on your birth chart.
#
# Hope this helps, and happy exploring
# Predicted Class: 1
# True Class: 1
#
#
# Test Case 9:
# Input Text: Would it be better if we were fixed? Well, that's a thought-provoking question. The concept of being "fixed" can be interpreted in different ways depending on the context. If you're referring to fixing our flaws or improving ourselves, then I believe it's a natural part of personal growth. We all have areas where we can strive to be better, whether it's in terms of our character, skills, or knowledge.
#
# However, if you're talking about being fixed in a way that implies conformity or losing our individuality, then it becomes a more complex issue. Diversity and uniqueness are what make our world so interesting and vibrant. Embracing our differences and celebrating our individuality can lead to innovation, creativity, and a richer human experience.
#
# Ultimately, I think it's important to strike a balance. We should always strive to improve ourselves and learn from our mistakes, but we should also cherish and embrace the things that make us who we are. It's through our imperfections and differences that we can truly grow and make a positive impact on the world around us.
# Predicted Class: 1
# True Class: 1
#
#
# Test Case 10:
# Input Text: What sodium concentration is best for brining different meats? When it comes to brining meats, the ideal sodium concentration can vary depending on personal preference and the type of meat you're working with. Generally, a good starting point is a brine solution with a salt concentration of around 5-8%. This means using about 50-80 grams of salt per liter of water.
#
# For poultry, such as chicken or turkey, a slightly higher salt concentration of around 6-8% can help enhance the flavor and retain moisture during cooking. Pork can benefit from a similar salt concentration as well.
#
# On the other hand, when brining beef or lamb, a lower salt concentration of around 5-6% is often preferred to avoid overpowering the natural flavors of the meat.
#
# Of course, these are just general guidelines, and you can always adjust the salt concentration to suit your taste. It's also worth considering other ingredients like sugar, herbs, spices, and aromatics to further enhance the flavor profile of your brine. Experimentation is key, and you might find your own perfect sodium concentration for different meats through trial and error.
# Predicted Class: 1
# True Class: 1

# %% [markdown]
# Let's test the model on some real world example

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification

# %%
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)
model.load_state_dict(torch.load('best_model2.pth'))
model.to(device)
model.eval()

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
inputs = [
    "I was just reading up on the ancient Theia planet that supposedly collided with earth, it likely had water, would it have had life? The short version is (1) we don't know and there's effectively no way we could know, but (2) it's broadly unlikely. For the first part, it's important to consider just how violent and destructive the impact between Theia and the Proto-Earth was. This is discussed in detail in a variety of publications, but the recent paper by Yuan et al., 2023 provides a nice summary and graphic (their Figure 1). Specifically, the impact between these two planets effectively completely melted the crust and much of the mantle of both Proto-Earth and Theia, with the core of Theia (and portions of Theia's mantle based on the results of Yuan et al) sinking and mixing with the Proto-Earth core / lower mantle. If there was hypothetically life on either Proto-Earth, Theia, or both, suffice to say, it would been eradicated during this event and all evidence would have been destroyed during the extreme melting and segregation processes that formed Earth as we know it (in terms of mass, etc.) and the Moon. For the second part, it's useful to consider the timeframes in involved. The impact of Theia with the Proto-Earth and the subsequent formation of the Moon, happened very early in the history of the solar system. The exact timing has been updated a few times, but recent results from Greer et al., 2023 suggest that this happened only ~110 million years after the formation of the solar system, or about 4.46 billion years ago. If we consider evidence for formation of life on Earth, whether we're thinking of the oldest preserved microfossil s(e.g., Schopf et al., 2017) or preservation of biosignatures more broadly (e.g., Homann et al., 2019), the earliest dates are ~3.5 billion years ago, i.e., nearly a full billion years after the Moon forming impact. It's hard to extrapolate from a dataset of 1, but if we consider that it took ~1 billion years for life to develop on Earth and that Theia as a planet had only existed for ~100 million years before it impacted the Proto-Earth, it becomes relatively unlikely that sufficient time had past for life to develop on either body prior to their collision. Even less so if we consider that this early period of the solar system would have been very chaotic, with lots of impacts from planetisemals and the like disrupting the surfaces of most every planetary body frequently.",
    "I was just reading up on the ancient Theia planet that supposedly collided with earth, it likely had water, would it have had life? The ancient Theia planet is a fascinating subject in the realm of planetary science. According to the Giant Impact Hypothesis, it is believed that Theia, a Mars-sized protoplanet, collided with early Earth around 4.5 billion years ago, leading to the formation of the Moon. This cataclysmic event had profound implications for the evolution of our planet. One intriguing aspect of Theia is the possibility that it harbored water. The presence of water on a celestial body is a crucial factor in the potential for life to exist. Water serves as a universal solvent, providing a medium for chemical reactions necessary for life as we know it. If Theia did indeed possess water, it would have increased the likelihood of life, at least in microbial form, having emerged on the planet. However, the question of whether Theia supported life is a complex one. While water is a crucial ingredient for life, it is not the sole determining factor. Other conditions, such as temperature, chemical composition, and the availability of organic molecules, also play pivotal roles. Theia's environment prior to the collision with Earth would have influenced its potential for life. The conditions on Theia prior to the impact are subject to speculation. It likely existed in the early solar system, where conditions were turbulent and dynamic. The protoplanetary disk from which Theia formed contained a mix of materials, including volatile compounds like water. This could suggest that Theia had the potential for habitability, at least in theory. However, it's important to note that the collision with Earth would have been a cataclysmic event. The immense energy released in the impact would have sterilized both Theia and Earth, obliterating any existing life forms. This renders the question of life on Theia moot in the context of the collision itself. In conclusion, while the presence of water on Theia may have increased the potential for life, the collision with Earth would have erased any such possibilities. The ancient Theia planet remains a captivating subject of scientific inquiry, offering insights into the early history of our solar system. The hypothetical existence of life on Theia, prior to the collision, highlights the intricate interplay of factors that determine habitability on celestial bodies."
    # Add more sentences if needed
    ]

# %%
encodings = tokenizer(inputs, truncation=True, padding=True, return_tensors='pt', max_length=512)
input_ids = encodings.input_ids.to(device)
attention_mask = encodings.attention_mask.to(device)

# %%
with torch.no_grad():
    outputs = model(input_ids, attention_mask=attention_mask)
    logits = outputs.logits
    predictions = torch.argmax(logits, dim=1).tolist()

# %%
for i, prediction in enumerate(predictions):
    print(f'Sentence {i+1} - Predicted Class: {prediction}')
# Out:
# Sentence 1 - Predicted Class: 0
# Sentence 2 - Predicted Class: 1
